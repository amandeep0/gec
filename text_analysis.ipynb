# %% [markdown]
# <a href="https://colab.research.google.com/github/amandeep0/gec/blob/master/text_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request
import pandas as pd

# %%
url_1 = "http://gutenberg.ca/ebooks/hemingwaye-sunalsorises/hemingwaye-sunalsorises-00-t.txt"
file_1 = urllib.request.urlopen(url_1).read()

url_2 = "http://gutenberg.ca/ebooks/hemingwaye-menwithoutwomen/hemingwaye-menwithoutwomen-00-t.txt"
file_2 = urllib.request.urlopen(url_2).read()

url_3 = "http://gutenberg.ca/ebooks/hemingwaye-acrosstheriver/hemingwaye-acrosstheriver-00-t.txt"
file_3 = urllib.request.urlopen(url_3).read()

url_4 = "http://gutenberg.ca/ebooks/hemingwaye-oldmanandthesea/hemingwaye-oldmanandthesea-00-t.txt"
file_4 = urllib.request.urlopen(url_4).read()

# %%
df = pd.DataFrame({'id':[1,2,3,4], 'text':[file_1,file_2,file_3,file_4], 'year':[1926, 1927,1950,1952]})
df.head()
# Out:
#    id                                               text  year
# 0   1  b'\n* A Project Gutenberg Canada Ebook *\n\nTh...  1926
# 1   2  b'\n* A Project Gutenberg Canada Ebook *\n\nTh...  1927
# 2   3  b'\n* A Project Gutenberg Canada Ebook *\n\nTh...  1950
# 3   4  b'\n* A Project Gutenberg Canada Ebook *\n\nTh...  1952

# %%
import re
# Remove punctuation
df['book_text_processed'] = df['text'].map(lambda x: re.sub('[,\.!?*]', '', str(x)[4:]))
# Convert the titles to lowercase
df['book_text_processed'] = df['book_text_processed'].map(lambda x: x.lower())
# Print out the first rows of papers
df['book_text_processed'].head()
# Out:
# 0     a project gutenberg canada ebook \n\nthis ebo...
# 1     a project gutenberg canada ebook \n\nthis ebo...
# 2     a project gutenberg canada ebook \n\nthis ebo...
# 3     a project gutenberg canada ebook \n\nthis ebo...
# Name: book_text_processed, dtype: object

# %%
from wordcloud import WordCloud
# Join the different processed titles together.
long_string = ','.join(list(df['book_text_processed'].values))
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(long_string)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F4610243F98>

# %%
# Out:
# [b'***************************************',
#  b'*                                     *',
#  b'*            HOW TO SOLVE:            *',
#  b'*                                     *',
#  b'*        THE ALPINE ENCOUNTER         *',
#  b'*                                     *',
#  b'***************************************',
#  b'',
#  b'THIS ADVENTURE IS TRULY AN ENIGMA.',
#  b'IT CAN BE SOLVED IN HUNDREDS OF MOVES',
#  b'OR HALF A DOZEN....',
#  b"WELL I HAVEN'T PLAYED THE HUNDRED MOVE",
#  b"VERSION...SO HERE'S THE SHORT ONE.",
#  b'',
#  b'COMMANDS IN BRACKETS:',
#  b'',
#  b'[N] THIS WILL PUT YOU INSIDE.',
#  b'[N] THIS WILL GET YOU NEAR THE DESK.',
#  b'[W] THIS WILL GET YOU TO THE REGIS-',
#  b'TRATION DESK.',
#  b'[REGISTER] A FORMALITY. FILL IN ANY',
#  b'NAME, ADDRESS, ETC.',
#  b'[WAIT] FOR A BLONDE WOMAN TO APPEAR.',
#  b"SHE'LL APPEAR AROUND 9:45.",
#  b'AT THAT POINT PRESS A KEY (NOT',
#  b'BEFORE.)',
#  b'[LOOK BACKPACK] THIS WILL UNCOVER A',
#  b'VASE.',
#  b'[TAKE VASE] YOU HAVE THE VITAL',
#  b'INFORMATION UNDER YOUR NOSE!',
#  b'[CALL INSPECTOR] YOU HAVE WON!',
#  b'',
#  b'THERE ARE MANY OTHER PLACES TO GO,',
#  b'THINGS TO DO, ETC.  BUT THE PARSER',
#  b'IS BAD AND THE GRAPHICS SLOPPY SO',
#  b'WHY BOTHER?',
#  b'',
#  b'THE EXPLANATION IS AS FOLLOWS:',
#  b'',
#  b'1) YOU FIND OUT YOUR MISSION,',
#  b'GETTING THE VASE BY READING THE',
#  b'NEWSPAPER.',
#  b'',
#  b"2) YOU FIND OUT THE WOMAN'S NAME",
#  b"(SINCE TYPING 'LOOK WOMAN' DOES",
#  b'NOT WORK) BY FOLLOWING HER AND',
#  b"'LISTEN'-ING TO HER CONVERSATION.",
#  b'IT IS RENEE.',
#  b'',
#  b'3) YOU FIND THE BACKPACK ON HER AND',
#  b'LOOK IN IT DUE TO COMMON SENSE.',
#  b'',
#  b'4) IF YOU CARRY THE VASE AROUND AND',
#  b'RUN INTO THE INSPECTOR HE ARRESTS',
#  b"YOU. SO YOU 'CALL INSPECTOR'.",
#  b'',
#  b'',
#  b'WRITTEN BY:',
#  b'',
#  b"PIRATE'S FRIEND",
#  b'*FRED SOFTWARE*']
